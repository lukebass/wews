# %% [markdown]
# # Forecasting Wildfires in British Columbia
# <hr><br>

# %% [markdown]
# ## Problem Statement
# <hr><br>

# %% [markdown]
# With trends set in motion by Climate Change, wildfires are becoming an increasingly devastating force for populations around the world. In some regions, such as California in the United States, they are a leading cause of property loss, habitat destruction, and GHG emissions. In the 2020 fire season, wildfires in California caused over $12$ Billion USD in damages. There is a high demand for prediction capabilities in regions such as this. Even small predictive ability on the order of minutes or hours could avert billions in damages by allowing first responders the ability to mitigate blazes before they spread, erect preventative measures, mobilize resources proactively to blaze sites, and begin evacuation efforts before residents are in peril. This project attempts to predict and forecast wildfires, using machine learning classifier algorithms, in British Columbia.

# %% [markdown]
# <br><br>

# %% [markdown]
# ## Data Collection
# <hr><br>

# %% [markdown]
# This project makes extensive use of Google Earth Engine. Before we begin, we must import **ee** and authenticate.

# %%
import ee
import numpy as np
import pandas as pd

ee.Authenticate()
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=8KfG1tSpHEGOQeKem3QaJHPGJiizoM4kFIrvoNcEn6g&tc=3JGfbwOyQOFoM9Fj6Blbhh8Zul6zxsnRuBILfe7CYK8&cc=2LMsfjl4osQKlPZzy5CEpO56xJFlY7fBlv5EK5YQ8z8>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=8KfG1tSpHEGOQeKem3QaJHPGJiizoM4kFIrvoNcEn6g&tc=3JGfbwOyQOFoM9Fj6Blbhh8Zul6zxsnRuBILfe7CYK8&cc=2LMsfjl4osQKlPZzy5CEpO56xJFlY7fBlv5EK5YQ8z8</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1AfJohXnTAJpZiWDJKKYp5H9hnAjWL9bEc4fW4y97DmE8AZM-Vkr0710CtP0
# Successfully saved authorization token.

# %% [markdown]
# <br>

# %% [markdown]
# All of the datasets used in this project come from NASA’s MODIS instrument aboard the Terra spacecraft. For more information, see [here](https://modis.gsfc.nasa.gov).
#
#
# *   [MODIS_061_MOD14A1](https://developers.google.com/earth-engine/datasets/catalog/MODIS_061_MOD14A1)
# *   [MODIS_061_MOD11A1](https://developers.google.com/earth-engine/datasets/catalog/MODIS_061_MOD11A1)
# *   [MODIS_061_MOD09GA](https://developers.google.com/earth-engine/datasets/catalog/MODIS_061_MOD09GA)

# %%
# Import MODIS_061_MOD14A1
ta = ee.ImageCollection('MODIS/061/MOD14A1').select('FireMask', 'MaxFRP')

# Import MODIS_061_MOD11A1
lst = ee.ImageCollection('MODIS/061/MOD11A1').select('LST_Day_1km', 'LST_Night_1km', 'Emis_31', 'Emis_32')

# Import MODIS_061_MOD09GA
sr = ee.ImageCollection('MODIS/061/MOD09GA').select('sur_refl_b01', 'sur_refl_b02', 'sur_refl_b03', 'sur_refl_b04', 'sur_refl_b05', 'sur_refl_b06', 'sur_refl_b07')

# %% [markdown]
# In order to extract data from the MODIS datasets, we must first define a `start` and `end` date, as well as a starting and stopping `longitude` and `latitude` and an associated `step` size. For this experiment, we decided to extract data from $2018$ to $2022$, starting at $-123.2$ `latitude` and $39.2$ `longitude`. With a `step` size of $0.02$ - roughly equivalent to $2$ km at the equator - we extract roughly $25$ samples per given $2$ km<sup>2</sup> bounding box per day. As we calculate a bounding box, we also assign it a region number. This allows us to divide Mendocino National Forest into ~$1500$ unique regions. In order to reduce the size of our dataset, we calculate the median values for our samples in our bounding boxes per day.

# %%
start = '2023-01-01'
stop = '2023-10-01'
startLon = -124.00
stopLon = -118.00
startLat = 50.00
stopLat = 52.00
step = 0.02
scale = 1000
on = ['id', 'longitude', 'latitude', 'time']

def getData():
    df = None
    region = 1
    
    for lat in np.arange(startLat, stopLat, step):
        for lon in np.arange(startLon, stopLon, step):
            print('Collecting data for region %d' % region)
            roi = ee.Geometry.BBox(lon, lat, lon + step, lat + step)

            ta_filter = ta.filterDate(start, stop).getRegion(roi, scale).getInfo()
            lst_filter = lst.filterDate(start, stop).getRegion(roi, scale).getInfo()
            sr_filter = sr.filterDate(start, stop).getRegion(roi, scale).getInfo()

            ta_df = pd.DataFrame(ta_filter[1:], columns=ta_filter[0])
            lst_df = pd.DataFrame(lst_filter[1:], columns=lst_filter[0])
            sr_df = pd.DataFrame(sr_filter[1:], columns=sr_filter[0])

            merged = ta_df.merge(lst_df, on=on).merge(sr_df, on=on)
            grouped = merged.groupby('id').median().reset_index()
            grouped['region'] = region
            region += 1
            df = grouped if df is None else pd.concat([df, grouped], ignore_index=True)

    df.to_csv('regions.csv', index=False)

getData()
# Out:
# Collecting data for region 1
# Collecting data for region 2
# Collecting data for region 3
# Collecting data for region 4
# Collecting data for region 5
# Collecting data for region 6
# Collecting data for region 7
# Collecting data for region 8
# Collecting data for region 9
# Collecting data for region 10
# Collecting data for region 11
# Collecting data for region 12
# Collecting data for region 13
# Collecting data for region 14
# Collecting data for region 15
# Collecting data for region 16
# Collecting data for region 17
# Collecting data for region 18
# Collecting data for region 19
# Collecting data for region 20
# Collecting data for region 21
# Collecting data for region 22
# Collecting data for region 23
# Collecting data for region 24
# Collecting data for region 25
# Collecting data for region 26
# Collecting data for region 27
# Collecting data for region 28
# Collecting data for region 29
# Collecting data for region 30
# Collecting data for region 31
# Collecting data for region 32
# Collecting data for region 33
# Collecting data for region 34
# Collecting data for region 35
# Collecting data for region 36
# Collecting data for region 37
# Collecting data for region 38
# Collecting data for region 39
# Collecting data for region 40
# Collecting data for region 41
# Collecting data for region 42
# Collecting data for region 43
# Collecting data for region 44
# Collecting data for region 45
# Collecting data for region 46
# Collecting data for region 47
# Collecting data for region 48
# Collecting data for region 49
# Collecting data for region 50
# Collecting data for region 51
# Collecting data for region 52
# Collecting data for region 53
# Collecting data for region 54
# Collecting data for region 55
# Collecting data for region 56
# Collecting data for region 57
# Collecting data for region 58
# Collecting data for region 59
# Collecting data for region 60
# Collecting data for region 61
# Collecting data for region 62
# Collecting data for region 63
# Collecting data for region 64
# Collecting data for region 65
# Collecting data for region 66
# Collecting data for region 67
# Collecting data for region 68
# Collecting data for region 69
# Collecting data for region 70
# Collecting data for region 71
# Collecting data for region 72
# Collecting data for region 73
# Collecting data for region 74
# Collecting data for region 75
# Collecting data for region 76
# Collecting data for region 77
# Collecting data for region 78
# Collecting data for region 79
# Collecting data for region 80
# Collecting data for region 81
# Collecting data for region 82
# Collecting data for region 83
# Collecting data for region 84
# Collecting data for region 85
# Collecting data for region 86
# Collecting data for region 87
# Collecting data for region 88
# Collecting data for region 89
# Collecting data for region 90
# Collecting data for region 91
# Collecting data for region 92
# Collecting data for region 93
# Collecting data for region 94
# Collecting data for region 95
# Collecting data for region 96
# Collecting data for region 97
# Collecting data for region 98
# Collecting data for region 99
# Collecting data for region 100
# Collecting data for region 101
# Collecting data for region 102
# Collecting data for region 103
# Collecting data for region 104
# Collecting data for region 105
# Collecting data for region 106
# Collecting data for region 107
# Collecting data for region 108
# Collecting data for region 109
# Collecting data for region 110
# Collecting data for region 111
# Collecting data for region 112
# Collecting data for region 113
# Collecting data for region 114
# Collecting data for region 115
# Collecting data for region 116
# Collecting data for region 117
# Collecting data for region 118
# Collecting data for region 119
# Collecting data for region 120
# Collecting data for region 121
# Collecting data for region 122
# Collecting data for region 123
# Collecting data for region 124
# Collecting data for region 125
# Collecting data for region 126
# Collecting data for region 127
# Collecting data for region 128
# Collecting data for region 129
# Collecting data for region 130
# Collecting data for region 131
# Collecting data for region 132
# Collecting data for region 133
# Collecting data for region 134
# Collecting data for region 135
# Collecting data for region 136
# Collecting data for region 137
# Collecting data for region 138
# Collecting data for region 139
# Collecting data for region 140
# Collecting data for region 141
# Collecting data for region 142
# Collecting data for region 143
# Collecting data for region 144
# Collecting data for region 145
# Collecting data for region 146
# Collecting data for region 147
# Collecting data for region 148
# Collecting data for region 149
# Collecting data for region 150
# Collecting data for region 151
# Collecting data for region 152
# Collecting data for region 153
# Collecting data for region 154
# Collecting data for region 155
# Collecting data for region 156
# Collecting data for region 157
# Collecting data for region 158
# Collecting data for region 159
# Collecting data for region 160
# Collecting data for region 161
# Collecting data for region 162
# Collecting data for region 163
# Collecting data for region 164
# Collecting data for region 165
# Collecting data for region 166
# Collecting data for region 167
# Collecting data for region 168
# Collecting data for region 169
# Collecting data for region 170
# Collecting data for region 171
# Collecting data for region 172
# Collecting data for region 173
# Collecting data for region 174
# Collecting data for region 175
# Collecting data for region 176
# Collecting data for region 177
# Collecting data for region 178
# Collecting data for region 179
# Collecting data for region 180
# Collecting data for region 181
# Collecting data for region 182
# Collecting data for region 183
# Collecting data for region 184
# Collecting data for region 185
# Collecting data for region 186
# Collecting data for region 187
# Collecting data for region 188
# Collecting data for region 189
# Collecting data for region 190
# Collecting data for region 191
# Collecting data for region 192
# Collecting data for region 193
# Collecting data for region 194
# Collecting data for region 195
# Collecting data for region 196
# Collecting data for region 197
# Collecting data for region 198
# Collecting data for region 199
# Collecting data for region 200
# Collecting data for region 201
# Collecting data for region 202
# Collecting data for region 203
# Collecting data for region 204
# Collecting data for region 205
# Collecting data for region 206
# Collecting data for region 207
# Collecting data for region 208
# Collecting data for region 209
# Collecting data for region 210
# Collecting data for region 211
# Collecting data for region 212
# Collecting data for region 213
# Collecting data for region 214
# Collecting data for region 215
# Collecting data for region 216
# Collecting data for region 217
# Collecting data for region 218
# Collecting data for region 219
# Collecting data for region 220
# Collecting data for region 221
# Collecting data for region 222
# Collecting data for region 223
# Collecting data for region 224
# Collecting data for region 225
# Collecting data for region 226
# Collecting data for region 227
# Collecting data for region 228
# Collecting data for region 229
# Collecting data for region 230
# Collecting data for region 231
# Collecting data for region 232
# Collecting data for region 233
# Collecting data for region 234
# Collecting data for region 235
# Collecting data for region 236
# Collecting data for region 237
# Collecting data for region 238
# Collecting data for region 239
# Collecting data for region 240
# Collecting data for region 241
# Collecting data for region 242
# Collecting data for region 243
# Collecting data for region 244
# Collecting data for region 245
# Collecting data for region 246
# Collecting data for region 247
# Collecting data for region 248
# Collecting data for region 249
# Collecting data for region 250
# Collecting data for region 251
# Collecting data for region 252
# Collecting data for region 253
# Collecting data for region 254
# Collecting data for region 255
# Collecting data for region 256
# Collecting data for region 257
# Collecting data for region 258
# Collecting data for region 259
# Collecting data for region 260
# Collecting data for region 261
# Collecting data for region 262
# Collecting data for region 263
# Collecting data for region 264
# Collecting data for region 265
# Collecting data for region 266
# Collecting data for region 267
# Collecting data for region 268
# Collecting data for region 269
# Collecting data for region 270
# Collecting data for region 271
# Collecting data for region 272
# Collecting data for region 273
# Collecting data for region 274
# Collecting data for region 275
# Collecting data for region 276
# Collecting data for region 277
# Collecting data for region 278
# Collecting data for region 279
# Collecting data for region 280
# Collecting data for region 281
# Collecting data for region 282
# Collecting data for region 283
# Collecting data for region 284
# Collecting data for region 285
# Collecting data for region 286
# Collecting data for region 287
# Collecting data for region 288
# Collecting data for region 289
# Collecting data for region 290
# Collecting data for region 291
# Collecting data for region 292
# Collecting data for region 293
# Collecting data for region 294
# Collecting data for region 295
# Collecting data for region 296
# Collecting data for region 297
# Collecting data for region 298
# Collecting data for region 299
# Collecting data for region 300
# Collecting data for region 301
# Collecting data for region 302
# Collecting data for region 303
# Collecting data for region 304
# Collecting data for region 305
# Collecting data for region 306
# Collecting data for region 307
# Collecting data for region 308
# Collecting data for region 309
# Collecting data for region 310
# Collecting data for region 311
# Collecting data for region 312
# Collecting data for region 313
# Collecting data for region 314
# Collecting data for region 315
# Collecting data for region 316
# Collecting data for region 317
# Collecting data for region 318
# Collecting data for region 319
# Collecting data for region 320
# Collecting data for region 321
# Collecting data for region 322
# Collecting data for region 323
# Collecting data for region 324
# Collecting data for region 325
# Collecting data for region 326
# Collecting data for region 327
# Collecting data for region 328
# Collecting data for region 329
# Collecting data for region 330
# Collecting data for region 331
# Collecting data for region 332
# Collecting data for region 333
# Collecting data for region 334
# Collecting data for region 335
# Collecting data for region 336
# Collecting data for region 337
# Collecting data for region 338
# Collecting data for region 339
# Collecting data for region 340
# Collecting data for region 341
# Collecting data for region 342
# Collecting data for region 343
# Collecting data for region 344
# Collecting data for region 345
# Collecting data for region 346
# Collecting data for region 347
# Collecting data for region 348
# Collecting data for region 349
# Collecting data for region 350
# Collecting data for region 351
# Collecting data for region 352
# Collecting data for region 353
# Collecting data for region 354
# Collecting data for region 355
# Collecting data for region 356
# Collecting data for region 357
# Collecting data for region 358
# Collecting data for region 359
# Collecting data for region 360
# Collecting data for region 361
# Collecting data for region 362
# Collecting data for region 363
# Collecting data for region 364
# Collecting data for region 365
# Collecting data for region 366
# Collecting data for region 367
# Collecting data for region 368
# Collecting data for region 369
# Collecting data for region 370
# Collecting data for region 371
# Collecting data for region 372
# Collecting data for region 373
# Collecting data for region 374
# Collecting data for region 375
# Collecting data for region 376
# Collecting data for region 377
# Collecting data for region 378
# Collecting data for region 379
# Collecting data for region 380
# Collecting data for region 381
# Collecting data for region 382
# Collecting data for region 383
# Collecting data for region 384
# Collecting data for region 385
# Collecting data for region 386
# Collecting data for region 387
# Collecting data for region 388
# Collecting data for region 389
# Collecting data for region 390
# Collecting data for region 391
# Collecting data for region 392
# Collecting data for region 393
# Collecting data for region 394
# Collecting data for region 395
# Collecting data for region 396
# Collecting data for region 397
# Collecting data for region 398
# Collecting data for region 399
# Collecting data for region 400
# Collecting data for region 401
# Collecting data for region 402
# Collecting data for region 403
# Collecting data for region 404
# Collecting data for region 405
# Collecting data for region 406
# Collecting data for region 407
# Collecting data for region 408
# Collecting data for region 409
# Collecting data for region 410
# Collecting data for region 411
# Collecting data for region 412
# Collecting data for region 413
# Collecting data for region 414
# Collecting data for region 415
# Collecting data for region 416
# Collecting data for region 417
# Collecting data for region 418
# Collecting data for region 419
# Collecting data for region 420
# Collecting data for region 421
# Collecting data for region 422
# Collecting data for region 423
# Collecting data for region 424
# Collecting data for region 425
# Collecting data for region 426
# Collecting data for region 427
# Collecting data for region 428
# Collecting data for region 429
# Collecting data for region 430
# Collecting data for region 431
# Collecting data for region 432
# Collecting data for region 433
# Collecting data for region 434
# Collecting data for region 435
# Collecting data for region 436
# Collecting data for region 437
# Collecting data for region 438
# Collecting data for region 439
# Collecting data for region 440
# Collecting data for region 441
# Collecting data for region 442
# Collecting data for region 443
# Collecting data for region 444
# Collecting data for region 445
# Collecting data for region 446
# Collecting data for region 447
# Collecting data for region 448
# Collecting data for region 449
# Collecting data for region 450
# Collecting data for region 451
# Collecting data for region 452
# Collecting data for region 453
# Collecting data for region 454
# Collecting data for region 455
# Collecting data for region 456
# Collecting data for region 457
# Collecting data for region 458
# Collecting data for region 459
# Collecting data for region 460
# Collecting data for region 461
# Collecting data for region 462
# Collecting data for region 463
# Collecting data for region 464
# Collecting data for region 465
# Collecting data for region 466
# Collecting data for region 467
# Collecting data for region 468
# Collecting data for region 469
# Collecting data for region 470
# Collecting data for region 471
# Collecting data for region 472
# Collecting data for region 473
# Collecting data for region 474
# Collecting data for region 475
# Collecting data for region 476
# Collecting data for region 477
# Collecting data for region 478
# Collecting data for region 479
# Collecting data for region 480
# Collecting data for region 481
# Collecting data for region 482
# Collecting data for region 483
# Collecting data for region 484
# Collecting data for region 485
# Collecting data for region 486
# Collecting data for region 487
# Collecting data for region 488
# Collecting data for region 489
# Collecting data for region 490
# Collecting data for region 491
# Collecting data for region 492
# Collecting data for region 493
# Collecting data for region 494
# Collecting data for region 495
# Collecting data for region 496
# Collecting data for region 497
# Collecting data for region 498
# Collecting data for region 499
# Collecting data for region 500
# Collecting data for region 501
# Collecting data for region 502
# Collecting data for region 503
# Collecting data for region 504
# Collecting data for region 505
# Collecting data for region 506
# Collecting data for region 507
# Collecting data for region 508
# Collecting data for region 509
# Collecting data for region 510
# Collecting data for region 511
# Collecting data for region 512
# Collecting data for region 513
# Collecting data for region 514
# Collecting data for region 515
# Collecting data for region 516
# Collecting data for region 517
# Collecting data for region 518
# Collecting data for region 519
# Collecting data for region 520
# Collecting data for region 521
# Collecting data for region 522
# Collecting data for region 523
# Collecting data for region 524
# Collecting data for region 525
# Collecting data for region 526
# Collecting data for region 527
# Collecting data for region 528
# Collecting data for region 529
# Collecting data for region 530
# Collecting data for region 531
# Collecting data for region 532
# Collecting data for region 533
# Collecting data for region 534
# Collecting data for region 535
# Collecting data for region 536
# Collecting data for region 537
# Collecting data for region 538
# Collecting data for region 539
# Collecting data for region 540
# Collecting data for region 541
# Collecting data for region 542
# Collecting data for region 543
# Collecting data for region 544
# Collecting data for region 545
# Collecting data for region 546
# Collecting data for region 547
# Collecting data for region 548
# Collecting data for region 549
# Collecting data for region 550
# Collecting data for region 551
# Collecting data for region 552
# Collecting data for region 553
# Collecting data for region 554
# Collecting data for region 555
# Collecting data for region 556
# Collecting data for region 557
# Collecting data for region 558
# Collecting data for region 559
# Collecting data for region 560
# Collecting data for region 561
# Collecting data for region 562
# Collecting data for region 563
# Collecting data for region 564
# Collecting data for region 565
# Collecting data for region 566
# Collecting data for region 567
# Collecting data for region 568
# Collecting data for region 569
# Collecting data for region 570
# Collecting data for region 571
# Collecting data for region 572
# Collecting data for region 573
# Collecting data for region 574
# Collecting data for region 575
# Collecting data for region 576
# Collecting data for region 577
# Collecting data for region 578
# Collecting data for region 579
# Collecting data for region 580
# Collecting data for region 581
# Collecting data for region 582
# Collecting data for region 583
# Collecting data for region 584
# Collecting data for region 585
# Collecting data for region 586
# Collecting data for region 587
# Collecting data for region 588
# Collecting data for region 589
# Collecting data for region 590
# Collecting data for region 591
# Collecting data for region 592
# Collecting data for region 593
# Collecting data for region 594
# Collecting data for region 595
# Collecting data for region 596
# Collecting data for region 597
# Collecting data for region 598
# Collecting data for region 599
# Collecting data for region 600
# Collecting data for region 601
# Collecting data for region 602
# Collecting data for region 603
# Collecting data for region 604
# Collecting data for region 605
# Collecting data for region 606
# Collecting data for region 607
# Collecting data for region 608
# Collecting data for region 609
# Collecting data for region 610
# Collecting data for region 611
# Collecting data for region 612
# Collecting data for region 613
# Collecting data for region 614
# Collecting data for region 615
# Collecting data for region 616
# Collecting data for region 617
# Collecting data for region 618
# Collecting data for region 619
# Collecting data for region 620
# Collecting data for region 621
# Collecting data for region 622
# Collecting data for region 623
# Collecting data for region 624
# Collecting data for region 625
# Collecting data for region 626
# Collecting data for region 627
# Collecting data for region 628
# Collecting data for region 629
# Collecting data for region 630
# Collecting data for region 631
# Collecting data for region 632
# Collecting data for region 633
# Collecting data for region 634
# Collecting data for region 635
# Collecting data for region 636
# Collecting data for region 637
# Collecting data for region 638
# Collecting data for region 639
# Collecting data for region 640
# Collecting data for region 641
# Collecting data for region 642
# Collecting data for region 643
# Collecting data for region 644
# Collecting data for region 645
# Collecting data for region 646
# Collecting data for region 647
# Collecting data for region 648
# Collecting data for region 649
# Collecting data for region 650
# Collecting data for region 651
# Collecting data for region 652
# Collecting data for region 653
# Collecting data for region 654
# Collecting data for region 655
# Collecting data for region 656
# Collecting data for region 657
# Collecting data for region 658
# Collecting data for region 659
# Collecting data for region 660
# Collecting data for region 661
# Collecting data for region 662
# Collecting data for region 663
# Collecting data for region 664
# Collecting data for region 665
# Collecting data for region 666
# Collecting data for region 667
# Collecting data for region 668
# Collecting data for region 669
# Collecting data for region 670
# Collecting data for region 671
# Collecting data for region 672
# Collecting data for region 673
# Collecting data for region 674
# Collecting data for region 675
# Collecting data for region 676
# Collecting data for region 677
# Collecting data for region 678
# Collecting data for region 679
# Collecting data for region 680
# Collecting data for region 681
# Collecting data for region 682
# Collecting data for region 683
# Collecting data for region 684
# Collecting data for region 685
# Collecting data for region 686
# Collecting data for region 687
# Collecting data for region 688
# Collecting data for region 689
# Collecting data for region 690
# Collecting data for region 691
# Collecting data for region 692
# Collecting data for region 693
# Collecting data for region 694
# Collecting data for region 695
# Collecting data for region 696
# Collecting data for region 697
# Collecting data for region 698
# Collecting data for region 699
# Collecting data for region 700
# Collecting data for region 701
# Collecting data for region 702
# Collecting data for region 703
# Collecting data for region 704
# Collecting data for region 705
# Collecting data for region 706
# Collecting data for region 707
# Collecting data for region 708
# Collecting data for region 709
# Collecting data for region 710
# Collecting data for region 711
# Collecting data for region 712
# Collecting data for region 713
# Collecting data for region 714
# Collecting data for region 715
# Collecting data for region 716
# Collecting data for region 717
# Collecting data for region 718
# Collecting data for region 719
# Collecting data for region 720
# Collecting data for region 721
# Collecting data for region 722
# Collecting data for region 723
# Collecting data for region 724
# Collecting data for region 725
# Collecting data for region 726
# Collecting data for region 727
# Collecting data for region 728
# Collecting data for region 729
# Collecting data for region 730
# Collecting data for region 731
# Collecting data for region 732
# Collecting data for region 733
# Collecting data for region 734
# Collecting data for region 735
# Collecting data for region 736
# Collecting data for region 737
# Collecting data for region 738
# Collecting data for region 739
# Collecting data for region 740
# Collecting data for region 741
# Collecting data for region 742
# Collecting data for region 743
# Collecting data for region 744
# Collecting data for region 745
# Collecting data for region 746
# Collecting data for region 747
# Collecting data for region 748
# Collecting data for region 749
# Collecting data for region 750
# Collecting data for region 751
# Collecting data for region 752
# Collecting data for region 753
# Collecting data for region 754
# Collecting data for region 755
# Collecting data for region 756
# Collecting data for region 757
# Collecting data for region 758
# Collecting data for region 759
# Collecting data for region 760
# Collecting data for region 761
# Collecting data for region 762
# Collecting data for region 763
# Collecting data for region 764
# Collecting data for region 765
# Collecting data for region 766
# Collecting data for region 767
# Collecting data for region 768
# Collecting data for region 769
# Collecting data for region 770
# Collecting data for region 771
# Collecting data for region 772
# Collecting data for region 773
# Collecting data for region 774
# Collecting data for region 775
# Collecting data for region 776
# Collecting data for region 777
# Collecting data for region 778
# Collecting data for region 779
# Collecting data for region 780
# Collecting data for region 781
# Collecting data for region 782
# Collecting data for region 783
# Collecting data for region 784
# Collecting data for region 785
# Collecting data for region 786
# Collecting data for region 787
# Collecting data for region 788
# Collecting data for region 789
# Collecting data for region 790
# Collecting data for region 791
# Collecting data for region 792
# Collecting data for region 793
# Collecting data for region 794
# Collecting data for region 795
# Collecting data for region 796
# Collecting data for region 797
# Collecting data for region 798
# Collecting data for region 799
# Collecting data for region 800
# Collecting data for region 801
# Collecting data for region 802
# Collecting data for region 803
# Collecting data for region 804
# Collecting data for region 805
# Collecting data for region 806
# Collecting data for region 807
# Collecting data for region 808
# Collecting data for region 809
# Collecting data for region 810
# Collecting data for region 811
# Collecting data for region 812
# Collecting data for region 813
# Collecting data for region 814
# Collecting data for region 815
# Collecting data for region 816
# Collecting data for region 817
# Collecting data for region 818
# Collecting data for region 819
# Collecting data for region 820
# Collecting data for region 821
# Collecting data for region 822
# Collecting data for region 823
# Collecting data for region 824
# Collecting data for region 825
# Collecting data for region 826
# Collecting data for region 827
# Collecting data for region 828
# Collecting data for region 829
# Collecting data for region 830
# Collecting data for region 831
# Collecting data for region 832
# Collecting data for region 833
# Collecting data for region 834
# Collecting data for region 835
# Collecting data for region 836
# Collecting data for region 837
# Collecting data for region 838
# Collecting data for region 839
# Collecting data for region 840
# Collecting data for region 841
# Collecting data for region 842
# Collecting data for region 843
# Collecting data for region 844
# Collecting data for region 845
# Collecting data for region 846
# Collecting data for region 847
# Collecting data for region 848
# Collecting data for region 849
# Collecting data for region 850
# Collecting data for region 851
# Collecting data for region 852
# Collecting data for region 853
# Collecting data for region 854
# Collecting data for region 855
# Collecting data for region 856
# Collecting data for region 857
# Collecting data for region 858
# Collecting data for region 859
# Collecting data for region 860
# Collecting data for region 861
# Collecting data for region 862
# Collecting data for region 863
# Collecting data for region 864
# Collecting data for region 865
# Collecting data for region 866
# Collecting data for region 867
# Collecting data for region 868
# Collecting data for region 869
# Collecting data for region 870
# Collecting data for region 871
# Collecting data for region 872
# Collecting data for region 873
# Collecting data for region 874
# Collecting data for region 875
# Collecting data for region 876
# Collecting data for region 877
# Collecting data for region 878
# Collecting data for region 879
# Collecting data for region 880
# Collecting data for region 881
# Collecting data for region 882
# Collecting data for region 883
# Collecting data for region 884
# Collecting data for region 885
# Collecting data for region 886
# Collecting data for region 887
# Collecting data for region 888
# Collecting data for region 889
# Collecting data for region 890
# Collecting data for region 891
# Collecting data for region 892
# Collecting data for region 893
# Collecting data for region 894
# Collecting data for region 895
# Collecting data for region 896
# Collecting data for region 897
# Collecting data for region 898
# Collecting data for region 899
# Collecting data for region 900
# Collecting data for region 901
# Collecting data for region 902
# Collecting data for region 903
# Collecting data for region 904
# Collecting data for region 905
# Collecting data for region 906
# Collecting data for region 907
# Collecting data for region 908
# Collecting data for region 909
# Collecting data for region 910
# Collecting data for region 911
# Collecting data for region 912
# Collecting data for region 913
# Collecting data for region 914
# Collecting data for region 915
# Collecting data for region 916
# Collecting data for region 917
# Collecting data for region 918
# Collecting data for region 919
# Collecting data for region 920
# Collecting data for region 921
# Collecting data for region 922
# Collecting data for region 923
# Collecting data for region 924
# Collecting data for region 925
# Collecting data for region 926
# Collecting data for region 927
# Collecting data for region 928
# Collecting data for region 929
# Collecting data for region 930
# Collecting data for region 931
# Collecting data for region 932
# Collecting data for region 933
# Collecting data for region 934
# Collecting data for region 935
# Collecting data for region 936
# Collecting data for region 937
# Collecting data for region 938
# Collecting data for region 939
# Collecting data for region 940
# Collecting data for region 941
# Collecting data for region 942
# Collecting data for region 943
# Collecting data for region 944
# Collecting data for region 945
# Collecting data for region 946
# Collecting data for region 947
# Collecting data for region 948
# Collecting data for region 949
# Collecting data for region 950
# Collecting data for region 951
# Collecting data for region 952
# Collecting data for region 953
# Collecting data for region 954
# Collecting data for region 955
# Collecting data for region 956
# Collecting data for region 957
# Collecting data for region 958
# Collecting data for region 959
# Collecting data for region 960
# Collecting data for region 961
# Collecting data for region 962
# Collecting data for region 963
# Collecting data for region 964
# Collecting data for region 965
# Collecting data for region 966
# Collecting data for region 967
# Collecting data for region 968
# Collecting data for region 969
# Collecting data for region 970
# Collecting data for region 971
# Collecting data for region 972
# Collecting data for region 973
# Collecting data for region 974
# Collecting data for region 975
# Collecting data for region 976
# Collecting data for region 977
# Collecting data for region 978
# Collecting data for region 979
# Collecting data for region 980
# Collecting data for region 981
# Collecting data for region 982
# Collecting data for region 983
# Collecting data for region 984
# Collecting data for region 985
# Collecting data for region 986
# Collecting data for region 987
# Collecting data for region 988
# Collecting data for region 989
# Collecting data for region 990
# Collecting data for region 991
# Collecting data for region 992
# Collecting data for region 993
# Collecting data for region 994
# Collecting data for region 995
# Collecting data for region 996
# Collecting data for region 997
# Collecting data for region 998
# Collecting data for region 999
# Collecting data for region 1000
# Collecting data for region 1001
# Collecting data for region 1002
# Collecting data for region 1003
# Collecting data for region 1004
# Collecting data for region 1005
# Collecting data for region 1006
# Collecting data for region 1007
# Collecting data for region 1008
# Collecting data for region 1009
# Collecting data for region 1010
# Collecting data for region 1011
# Collecting data for region 1012
# Collecting data for region 1013
# Collecting data for region 1014
# Collecting data for region 1015
# Collecting data for region 1016
# Collecting data for region 1017
# Collecting data for region 1018
# Collecting data for region 1019
# Collecting data for region 1020
# Collecting data for region 1021
# Collecting data for region 1022
# Collecting data for region 1023
# Collecting data for region 1024
# Collecting data for region 1025
# Collecting data for region 1026
# Collecting data for region 1027
# Collecting data for region 1028
# Collecting data for region 1029
# Collecting data for region 1030
# Collecting data for region 1031
# Collecting data for region 1032
# Collecting data for region 1033
# Collecting data for region 1034
# Collecting data for region 1035
# Collecting data for region 1036
# Collecting data for region 1037
# Collecting data for region 1038
# Collecting data for region 1039
# Collecting data for region 1040
# Collecting data for region 1041
# Collecting data for region 1042
# Collecting data for region 1043
# Collecting data for region 1044
# Collecting data for region 1045
# Collecting data for region 1046
# Collecting data for region 1047
# Collecting data for region 1048
# Collecting data for region 1049
# Collecting data for region 1050
# Collecting data for region 1051
# Collecting data for region 1052
# Collecting data for region 1053
# Collecting data for region 1054
# Collecting data for region 1055
# Collecting data for region 1056
# Collecting data for region 1057
# Collecting data for region 1058
# Collecting data for region 1059
# Collecting data for region 1060
# Collecting data for region 1061
# Collecting data for region 1062
# Collecting data for region 1063
# Collecting data for region 1064
# Collecting data for region 1065
# Collecting data for region 1066
# Collecting data for region 1067
# Collecting data for region 1068
# Collecting data for region 1069
# Collecting data for region 1070
# Collecting data for region 1071
# Collecting data for region 1072
# Collecting data for region 1073
# Collecting data for region 1074
# Collecting data for region 1075
# Collecting data for region 1076
# Collecting data for region 1077
# Collecting data for region 1078
# Collecting data for region 1079
# Collecting data for region 1080
# Collecting data for region 1081
# Collecting data for region 1082
# Collecting data for region 1083
# Collecting data for region 1084
# Collecting data for region 1085
# Collecting data for region 1086
# Collecting data for region 1087
# Collecting data for region 1088
# Collecting data for region 1089
# Collecting data for region 1090
# Collecting data for region 1091
# Collecting data for region 1092
# Collecting data for region 1093
# Collecting data for region 1094
# Collecting data for region 1095
# Collecting data for region 1096
# Collecting data for region 1097
# Collecting data for region 1098
# Collecting data for region 1099
# Collecting data for region 1100
# Collecting data for region 1101
# Collecting data for region 1102
# Collecting data for region 1103
# Collecting data for region 1104
# Collecting data for region 1105
# Collecting data for region 1106
# Collecting data for region 1107
# Collecting data for region 1108
# Collecting data for region 1109
# Collecting data for region 1110
# Collecting data for region 1111
# Collecting data for region 1112
# Collecting data for region 1113
# Collecting data for region 1114
# Collecting data for region 1115
# Collecting data for region 1116
# Collecting data for region 1117
# Collecting data for region 1118
# Collecting data for region 1119
# Collecting data for region 1120
# Collecting data for region 1121
# Collecting data for region 1122
# Collecting data for region 1123
# Collecting data for region 1124
# Collecting data for region 1125
# Collecting data for region 1126
# Collecting data for region 1127
# Collecting data for region 1128
# Collecting data for region 1129
# Collecting data for region 1130
# Collecting data for region 1131
# Collecting data for region 1132
# Collecting data for region 1133
# Collecting data for region 1134
# Collecting data for region 1135
# Collecting data for region 1136
# Collecting data for region 1137
# Collecting data for region 1138
# Collecting data for region 1139
# Collecting data for region 1140
# Collecting data for region 1141
# Collecting data for region 1142
# Collecting data for region 1143
# Collecting data for region 1144
# Collecting data for region 1145
# Collecting data for region 1146
# Collecting data for region 1147
# Collecting data for region 1148
# Collecting data for region 1149
# Collecting data for region 1150
# Collecting data for region 1151
# Collecting data for region 1152
# Collecting data for region 1153
# Collecting data for region 1154
# Collecting data for region 1155
# Collecting data for region 1156
# Collecting data for region 1157
# Collecting data for region 1158
# Collecting data for region 1159
# Collecting data for region 1160
# Collecting data for region 1161
# Collecting data for region 1162
# Collecting data for region 1163
# Collecting data for region 1164
# Collecting data for region 1165
# Collecting data for region 1166
# Collecting data for region 1167
# Collecting data for region 1168
# Collecting data for region 1169
# Collecting data for region 1170
# Collecting data for region 1171
# Collecting data for region 1172
# Collecting data for region 1173
# Collecting data for region 1174
# Collecting data for region 1175
# Collecting data for region 1176
# Collecting data for region 1177
# Collecting data for region 1178
# Collecting data for region 1179
# Collecting data for region 1180
# Collecting data for region 1181
# Collecting data for region 1182
# Collecting data for region 1183
# Collecting data for region 1184
# Collecting data for region 1185
# Collecting data for region 1186
# Collecting data for region 1187
# Collecting data for region 1188
# Collecting data for region 1189
# Collecting data for region 1190
# Collecting data for region 1191
# Collecting data for region 1192
# Collecting data for region 1193
# Collecting data for region 1194
# Collecting data for region 1195
# Collecting data for region 1196
# Collecting data for region 1197
# Collecting data for region 1198
# Collecting data for region 1199
# Collecting data for region 1200
# Collecting data for region 1201
# Collecting data for region 1202
# Collecting data for region 1203
# Collecting data for region 1204
# Collecting data for region 1205
# Collecting data for region 1206
# Collecting data for region 1207
# Collecting data for region 1208
# Collecting data for region 1209
# Collecting data for region 1210
# Collecting data for region 1211
# Collecting data for region 1212
# Collecting data for region 1213
# Collecting data for region 1214
# Collecting data for region 1215
# Collecting data for region 1216
# Collecting data for region 1217
# Collecting data for region 1218
# Collecting data for region 1219
# Collecting data for region 1220
# Collecting data for region 1221
# Collecting data for region 1222
# Collecting data for region 1223
# Collecting data for region 1224
# Collecting data for region 1225
# Collecting data for region 1226
# Collecting data for region 1227
# Collecting data for region 1228
# Collecting data for region 1229
# Collecting data for region 1230
# Collecting data for region 1231
# Collecting data for region 1232
# Collecting data for region 1233
# Collecting data for region 1234
# Collecting data for region 1235
# Collecting data for region 1236
# Collecting data for region 1237
# Collecting data for region 1238
# Collecting data for region 1239
# Collecting data for region 1240
# Collecting data for region 1241
# Collecting data for region 1242
# Collecting data for region 1243
# Collecting data for region 1244
# Collecting data for region 1245
# Collecting data for region 1246
# Collecting data for region 1247
# Collecting data for region 1248
# Collecting data for region 1249
# Collecting data for region 1250
# Collecting data for region 1251
# Collecting data for region 1252
# Collecting data for region 1253
# Collecting data for region 1254
# Collecting data for region 1255
# Collecting data for region 1256
# Collecting data for region 1257
# Collecting data for region 1258
# Collecting data for region 1259
# Collecting data for region 1260
# Collecting data for region 1261
# Collecting data for region 1262
# Collecting data for region 1263
# Collecting data for region 1264
# Collecting data for region 1265
# Collecting data for region 1266
# Collecting data for region 1267
# Collecting data for region 1268
# Collecting data for region 1269
# Collecting data for region 1270
# Collecting data for region 1271
# Collecting data for region 1272
# Collecting data for region 1273
# Collecting data for region 1274
# Collecting data for region 1275
# Collecting data for region 1276
# Collecting data for region 1277
# Collecting data for region 1278
# Collecting data for region 1279
# Collecting data for region 1280
# Collecting data for region 1281
# Collecting data for region 1282
# Collecting data for region 1283
# Collecting data for region 1284
# Collecting data for region 1285
# Collecting data for region 1286
# Collecting data for region 1287
# Collecting data for region 1288
# Collecting data for region 1289
# Collecting data for region 1290
# Collecting data for region 1291
# Collecting data for region 1292
# Collecting data for region 1293
# Collecting data for region 1294
# Collecting data for region 1295
# Collecting data for region 1296
# Collecting data for region 1297
# Collecting data for region 1298
# Collecting data for region 1299
# Collecting data for region 1300
# Collecting data for region 1301
# Collecting data for region 1302
# Collecting data for region 1303
# Collecting data for region 1304
# Collecting data for region 1305
# Collecting data for region 1306
# Collecting data for region 1307
# Collecting data for region 1308
# Collecting data for region 1309
# Collecting data for region 1310
# Collecting data for region 1311
# Collecting data for region 1312
# Collecting data for region 1313
# Collecting data for region 1314
# Collecting data for region 1315
# Collecting data for region 1316
# Collecting data for region 1317
# Collecting data for region 1318
# Collecting data for region 1319
# Collecting data for region 1320
# Collecting data for region 1321
# Collecting data for region 1322
# Collecting data for region 1323
# Collecting data for region 1324
# Collecting data for region 1325
# Collecting data for region 1326
# Collecting data for region 1327
# Collecting data for region 1328
# Collecting data for region 1329
# Collecting data for region 1330
# Collecting data for region 1331
# Collecting data for region 1332
# Collecting data for region 1333
# Collecting data for region 1334
# Collecting data for region 1335
# Collecting data for region 1336
# Collecting data for region 1337
# Collecting data for region 1338
# Collecting data for region 1339
# Collecting data for region 1340
# Collecting data for region 1341
# Collecting data for region 1342
# Collecting data for region 1343
# Collecting data for region 1344
# Collecting data for region 1345
# Collecting data for region 1346
# Collecting data for region 1347
# Collecting data for region 1348
# Collecting data for region 1349
# Collecting data for region 1350
# Collecting data for region 1351
# Collecting data for region 1352
# Collecting data for region 1353
# Collecting data for region 1354
# Collecting data for region 1355
# Collecting data for region 1356
# Collecting data for region 1357
# Collecting data for region 1358
# Collecting data for region 1359
# Collecting data for region 1360
# Collecting data for region 1361
# Collecting data for region 1362
# Collecting data for region 1363
# Collecting data for region 1364
# Collecting data for region 1365
# Collecting data for region 1366
# Collecting data for region 1367
# Collecting data for region 1368
# Collecting data for region 1369
# Collecting data for region 1370
# Collecting data for region 1371
# Collecting data for region 1372
# Collecting data for region 1373
# Collecting data for region 1374
# Collecting data for region 1375
# Collecting data for region 1376
# Collecting data for region 1377
# Collecting data for region 1378
# Collecting data for region 1379
# Collecting data for region 1380
# Collecting data for region 1381
# Collecting data for region 1382
# Collecting data for region 1383
# Collecting data for region 1384
# Collecting data for region 1385
# Collecting data for region 1386
# Collecting data for region 1387
# Collecting data for region 1388
# Collecting data for region 1389
# Collecting data for region 1390
# Collecting data for region 1391
# Collecting data for region 1392
# Collecting data for region 1393
# Collecting data for region 1394
# Collecting data for region 1395
# Collecting data for region 1396
# Collecting data for region 1397
# Collecting data for region 1398
# Collecting data for region 1399
# Collecting data for region 1400
# Collecting data for region 1401
# Collecting data for region 1402
# Collecting data for region 1403
# Collecting data for region 1404
# Collecting data for region 1405
# Collecting data for region 1406
# Collecting data for region 1407
# Collecting data for region 1408
# Collecting data for region 1409
# Collecting data for region 1410
# Collecting data for region 1411
# Collecting data for region 1412
# Collecting data for region 1413
# Collecting data for region 1414
# Collecting data for region 1415
# Collecting data for region 1416
# Collecting data for region 1417
# Collecting data for region 1418
# Collecting data for region 1419
# Collecting data for region 1420
# Collecting data for region 1421
# Collecting data for region 1422
# Collecting data for region 1423
# Collecting data for region 1424
# Collecting data for region 1425
# Collecting data for region 1426
# Collecting data for region 1427
# Collecting data for region 1428
# Collecting data for region 1429
# Collecting data for region 1430
# Collecting data for region 1431
# Collecting data for region 1432
# Collecting data for region 1433
# Collecting data for region 1434
# Collecting data for region 1435
# Collecting data for region 1436
# Collecting data for region 1437
# Collecting data for region 1438
# Collecting data for region 1439
# Collecting data for region 1440
# Collecting data for region 1441
# Collecting data for region 1442
# Collecting data for region 1443
# Collecting data for region 1444
# Collecting data for region 1445
# Collecting data for region 1446
# Collecting data for region 1447
# Collecting data for region 1448
# Collecting data for region 1449
# Collecting data for region 1450
# Collecting data for region 1451
# Collecting data for region 1452
# Collecting data for region 1453
# Collecting data for region 1454
# Collecting data for region 1455
# Collecting data for region 1456
# Collecting data for region 1457
# Collecting data for region 1458
# Collecting data for region 1459
# Collecting data for region 1460
# Collecting data for region 1461
# Collecting data for region 1462
# Collecting data for region 1463
# Collecting data for region 1464
# Collecting data for region 1465
# Collecting data for region 1466
# Collecting data for region 1467
# Collecting data for region 1468
# Collecting data for region 1469
# Collecting data for region 1470
# Collecting data for region 1471
# Collecting data for region 1472
# Collecting data for region 1473
# Collecting data for region 1474
# Collecting data for region 1475
# Collecting data for region 1476
# Collecting data for region 1477
# Collecting data for region 1478
# Collecting data for region 1479
# Collecting data for region 1480
# Collecting data for region 1481
# Collecting data for region 1482
# Collecting data for region 1483
# Collecting data for region 1484
# Collecting data for region 1485
# Collecting data for region 1486
# Collecting data for region 1487
# Collecting data for region 1488
# Collecting data for region 1489
# Collecting data for region 1490
# Collecting data for region 1491
# Collecting data for region 1492
# Collecting data for region 1493
# Collecting data for region 1494
# Collecting data for region 1495
# Collecting data for region 1496
# Collecting data for region 1497
# Collecting data for region 1498
# Collecting data for region 1499
# Collecting data for region 1500
# Collecting data for region 1501
# Collecting data for region 1502
# Collecting data for region 1503
# Collecting data for region 1504
# Collecting data for region 1505
# Collecting data for region 1506
# Collecting data for region 1507
# Collecting data for region 1508
# Collecting data for region 1509
# Collecting data for region 1510
# Collecting data for region 1511
# Collecting data for region 1512
# Collecting data for region 1513
# Collecting data for region 1514
# Collecting data for region 1515
# Collecting data for region 1516
# Collecting data for region 1517
# Collecting data for region 1518
# Collecting data for region 1519
# Collecting data for region 1520
# Collecting data for region 1521
# Collecting data for region 1522
# Collecting data for region 1523
# Collecting data for region 1524
# Collecting data for region 1525
# Collecting data for region 1526
# Collecting data for region 1527
# Collecting data for region 1528
# Collecting data for region 1529
# Collecting data for region 1530
# Collecting data for region 1531
# Collecting data for region 1532
# Collecting data for region 1533
# Collecting data for region 1534
# Collecting data for region 1535
# Collecting data for region 1536
# Collecting data for region 1537
# Collecting data for region 1538
# Collecting data for region 1539
# Collecting data for region 1540
# Collecting data for region 1541
# Collecting data for region 1542
# Collecting data for region 1543
# Collecting data for region 1544
# Collecting data for region 1545
# Collecting data for region 1546
# Collecting data for region 1547
# Collecting data for region 1548
# Collecting data for region 1549
# Collecting data for region 1550

# %% [markdown]
# <br><br>

# %% [markdown]
# ## 1. Import Libraries
# <hr>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import eli5
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import make_pipeline
from imblearn.pipeline import make_pipeline as imb_make_pipeline
from imblearn.over_sampling import SMOTE
from sklearn.compose import make_column_transformer
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from lightgbm.sklearn import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.metrics import average_precision_score, precision_recall_curve, roc_auc_score, roc_curve, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, cross_validate

# %% [markdown]
# <br><br>

# %% [markdown]
# ## 2. Problem Discussion
# <hr><br>

# %%
df = pd.read_csv('regions.csv')
df = df.rename(columns={'id':'date', 'FireMask':'fire_today', 'LST_Day_1km':'lst_day', 'LST_Night_1km':'lst_night', 'Emis_31':'emis_31', 'Emis_32':'emis_32'})
df['date'] = pd.to_datetime(df['date'], format='%Y_%m_%d')
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2263000 entries, 0 to 2262999
# Data columns (total 17 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   date          2263000 non-null  datetime64[ns]
#  1   longitude     2263000 non-null  float64
#  2   latitude      2263000 non-null  float64
#  3   time          2263000 non-null  float64
#  4   fire_today    2263000 non-null  float64
#  5   lst_day       1587659 non-null  float64
#  6   lst_night     1523097 non-null  float64
#  7   emis_31       1832925 non-null  float64
#  8   emis_32       1832925 non-null  float64
#  9   sur_refl_b01  2253700 non-null  float64
#  10  sur_refl_b02  2253682 non-null  float64
#  11  sur_refl_b03  2253700 non-null  float64
#  12  sur_refl_b04  2253700 non-null  float64
#  13  sur_refl_b05  2253700 non-null  float64
#  14  sur_refl_b06  2253700 non-null  float64
#  15  sur_refl_b07  2253697 non-null  float64
#  16  region        2263000 non-null  int64
# dtypes: datetime64[ns](1), float64(15), int64(1)
# memory usage: 293.5 MB

# %% [markdown]
# As we can see above, after joining the three datasets, we're left with a dataframe with $17$ features. This dataset contains $2,263,000$ entries or examples and occupies ~$300$ MB of memory. Regarding the features, we will use the `fire_today` field to calculate our target variable: `fire_tomorrow`. Recall that the `fire_today` field takes on the following values:
#
# 1. Not processed (obsolete; not used since Collection 1)
# 2. Not processed (other reason)
# 3. Non-fire water pixel
# 4. Cloud (land or water)
# 5. Non-fire land pixel
# 6. Unknown (land or water)
# 7. Fire (low confidence, land or water)
# 8. Fire (nominal confidence, land or water)
# 9. Fire (high confidence, land or water)
#
# Ideally, we'd like to convert this problem into a binary classification problem: $0$ means no fire and $1$ means fire. Although the `fire_today` field provides confidence levels for fire, we'll consider all three fire values ($7$, $8$, and $9$) as fire. The rationale here is that if our model predicts a False Positive, fire when there is no fire, then it would be predicting in an overly cautious manner. In the case of wildfires, we believe this is an acceptable course of action. The following line of code does exactly this: transforms the `fire_today` field to indicate a $0$ (no fire) for all values less than $7$ and a $1$ (fire) for all values greater to or equal than $7$.

# %%
df['fire_today'] = np.where(df['fire_today'] >= 7, 1, 0)

# %% [markdown]
# <br><br>

# %% [markdown]
# ## 3. Exploratory Data Analysis
# <hr><br>

# %% [markdown]
# The first form of feature engineering we'll perform is extracting the `month` and `year` from the `date` field. From here, we can use one-hot encoding on our new features to give our model more useful information to extract and learn from.

# %%
df = df.assign(month=df['date'].apply(lambda x: x.month_name()))
df = df.assign(year=df['date'].apply(lambda x: x.year))
df
# Out:
#               date   longitude   latitude          time  fire_today  lst_day  \
# 0       2018-01-01 -123.190466  39.209216  1.514765e+12           0  14334.0
# 1       2018-01-02 -123.190466  39.209216  1.514851e+12           0      NaN
# 2       2018-01-03 -123.190466  39.209216  1.514938e+12           0      NaN
# 3       2018-01-04 -123.190466  39.209216  1.515024e+12           0      NaN
# 4       2018-01-05 -123.190466  39.209216  1.515110e+12           0      NaN
# ...            ...         ...        ...           ...         ...      ...
# 2262995 2021-12-27 -122.590841  40.190626  1.640563e+12           0  13899.0
# 2262996 2021-12-28 -122.590841  40.190626  1.640650e+12           0      NaN
# 2262997 2021-12-29 -122.590841  40.190626  1.640736e+12           0      NaN
# 2262998 2021-12-30 -122.590841  40.190626  1.640822e+12           0      NaN
# 2262999 2021-12-31 -122.590841  40.190626  1.640909e+12           0  14071.0
#
#          lst_night  emis_31  emis_32  sur_refl_b01  sur_refl_b02  \
# 0              NaN    246.5    245.0         474.0        1475.0
# 1              NaN      NaN      NaN        3617.0        4341.0
# 2              NaN      NaN      NaN        6695.0        6679.0
# 3          13670.5    246.0    247.0        3736.0        3838.0
# 4              NaN      NaN      NaN        5094.5        5238.0
# ...            ...      ...      ...           ...           ...
# 2262995        NaN    247.0    248.0         587.0        2407.0
# 2262996        NaN      NaN      NaN        7189.5        7037.5
# 2262997        NaN      NaN      NaN        3937.0        4793.5
# 2262998    13631.5    247.0    248.5        1483.0        3356.0
# 2262999    13638.0    246.0    248.0         515.0        2261.0
#
#          sur_refl_b03  sur_refl_b04  sur_refl_b05  sur_refl_b06  sur_refl_b07  \
# 0               261.0         524.0        1633.0        1323.0         542.0
# 1              3635.5        3650.0        4089.0        2976.0        1894.0
# 2              6871.0        6756.0        6334.0        4022.0        2287.0
# 3              4016.0        3853.0        3841.0        3324.0        1876.0
# 4              5236.0        5139.0        4709.0        3517.5        1836.0
# ...               ...           ...           ...           ...           ...
# 2262995         319.5         705.0        2639.5        2008.0         943.0
# 2262996        7350.5        7296.5        5596.0        2135.5        1059.5
# 2262997        4217.0        4071.5        4819.0        4348.0        3030.0
# 2262998        1102.0        1545.0        3459.5        2494.0        1245.5
# 2262999         221.0         523.0        2455.0        1812.0         793.0
#
#          region     month  year
# 0             1   January  2018
# 1             1   January  2018
# 2             1   January  2018
# 3             1   January  2018
# 4             1   January  2018
# ...         ...       ...   ...
# 2262995    1550  December  2021
# 2262996    1550  December  2021
# 2262997    1550  December  2021
# 2262998    1550  December  2021
# 2262999    1550  December  2021
#
# [2263000 rows x 19 columns]

# %% [markdown]
# <br>

# %%
df.info(verbose=True, show_counts=True)
df.describe(include='all', datetime_is_numeric=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2263000 entries, 0 to 2262999
# Data columns (total 19 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   date          2263000 non-null  datetime64[ns]
#  1   longitude     2263000 non-null  float64
#  2   latitude      2263000 non-null  float64
#  3   time          2263000 non-null  float64
#  4   fire_today    2263000 non-null  int64
#  5   lst_day       1587659 non-null  float64
#  6   lst_night     1523097 non-null  float64
#  7   emis_31       1832925 non-null  float64
#  8   emis_32       1832925 non-null  float64
#  9   sur_refl_b01  2253700 non-null  float64
#  10  sur_refl_b02  2253682 non-null  float64
#  11  sur_refl_b03  2253700 non-null  float64
#  12  sur_refl_b04  2253700 non-null  float64
#  13  sur_refl_b05  2253700 non-null  float64
#  14  sur_refl_b06  2253700 non-null  float64
#  15  sur_refl_b07  2253697 non-null  float64
#  16  region        2263000 non-null  int64
#  17  month         2263000 non-null  object
#  18  year          2263000 non-null  int64
# dtypes: datetime64[ns](1), float64(14), int64(3), object(1)
# memory usage: 328.0+ MB
#                                  date     longitude      latitude  \
# count                         2263000  2.263000e+06  2.263000e+06
# unique                            NaN           NaN           NaN
# top                               NaN           NaN           NaN
# freq                              NaN           NaN           NaN
# mean    2019-12-31 13:31:43.561642752 -1.228901e+02  3.970001e+01
# min               2018-01-01 00:00:00 -1.231905e+02  3.920922e+01
# 25%               2018-12-31 18:00:00 -1.230512e+02  3.944952e+01
# 50%               2019-12-31 12:00:00 -1.228895e+02  3.969992e+01
# 75%               2020-12-30 06:00:00 -1.227301e+02  3.995033e+01
# max               2021-12-31 00:00:00 -1.225908e+02  4.019063e+01
# std                               NaN  1.789208e-01  2.886006e-01
#
#                 time    fire_today       lst_day     lst_night       emis_31  \
# count   2.263000e+06  2.263000e+06  1.587659e+06  1.523097e+06  1.832925e+06
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    1.577799e+12  1.201944e-03  1.484087e+04  1.420667e+04  2.474912e+02
# min     1.514765e+12  0.000000e+00  1.249100e+04  1.254000e+04  2.420000e+02
# 25%     1.546279e+12  0.000000e+00  1.441700e+04  1.390500e+04  2.470000e+02
# 50%     1.577794e+12  0.000000e+00  1.489800e+04  1.422600e+04  2.480000e+02
# 75%     1.609308e+12  0.000000e+00  1.525900e+04  1.452300e+04  2.480000e+02
# max     1.640909e+12  1.000000e+00  1.672850e+04  1.663300e+04  2.520000e+02
# std     3.642357e+10  3.464823e-02  5.691097e+02  3.838855e+02  9.691421e-01
#
#              emis_32  sur_refl_b01  sur_refl_b02  sur_refl_b03  sur_refl_b04  \
# count   1.832925e+06  2.253700e+06  2.253682e+06  2.253700e+06  2.253700e+06
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    2.487363e+02  1.848637e+03  2.917769e+03  1.681660e+03  1.832310e+03
# min     2.410000e+02 -1.000000e+02 -1.000000e+02 -1.000000e+02 -1.000000e+02
# 25%     2.480000e+02  4.060000e+02  1.660000e+03  2.165000e+02  4.090000e+02
# 50%     2.490000e+02  6.710000e+02  2.203500e+03  3.700000e+02  6.145000e+02
# 75%     2.490000e+02  2.223000e+03  3.184000e+03  2.168000e+03  2.249500e+03
# max     2.500000e+02  1.600000e+04  1.600000e+04  1.600000e+04  1.600000e+04
# std     6.774379e-01  2.375162e+03  1.979775e+03  2.452515e+03  2.378083e+03
#
#         sur_refl_b05  sur_refl_b06  sur_refl_b07        region    month  \
# count   2.253700e+06  2.253700e+06  2.253697e+06  2.263000e+06  2263000
# unique           NaN           NaN           NaN           NaN       12
# top              NaN           NaN           NaN           NaN  January
# freq             NaN           NaN           NaN           NaN   192200
# mean    2.847253e+03  2.014045e+03  1.188653e+03  7.755000e+02      NaN
# min    -1.000000e+02 -1.000000e+02 -1.000000e+02  1.000000e+00      NaN
# 25%     1.778500e+03  1.274000e+03  6.390000e+02  3.880000e+02      NaN
# 50%     2.361000e+03  1.766000e+03  1.017000e+03  7.755000e+02      NaN
# 75%     3.169000e+03  2.429000e+03  1.531000e+03  1.163000e+03      NaN
# max     1.437350e+04  9.438000e+03  8.913500e+03  1.550000e+03      NaN
# std     1.595718e+03  1.077885e+03  7.609795e+02  4.474465e+02      NaN
#
#                 year
# count   2.263000e+06
# unique           NaN
# top              NaN
# freq             NaN
# mean    2.019499e+03
# min     2.018000e+03
# 25%     2.018750e+03
# 50%     2.019500e+03
# 75%     2.020000e+03
# max     2.021000e+03
# std     1.117421e+00

# %% [markdown]
# Examining the above tables, we see that there are $2,263,000$ entries or examples in our training set. With the exception of the `date` and `month` features, all of our columns are numeric: `int64` or `float64`. Recall that we've transformed `fire_today` into a binary feature, where $0$ means no fire and $1$ means fire. All of the numeric features use a variety of scales and will need to be scaled appropriately before training our model. Furthermore, the following features contain missing values which will need to be imputed: `lst_day`, `lst_night`, `emis_31`, `emis_32`, `sur_refl_b01`, `sur_refl_b02`, `sur_refl_b03`, `sur_refl_b04`, `sur_refl_b05`, `sur_refl_b06`, `sur_refl_b07`.

# %% [markdown]
# <br>

# %%
df['fire_today'].value_counts(normalize=True)
# Out:
# 0    0.998798
# 1    0.001202
# Name: fire_today, dtype: float64

# %% [markdown]
# As we can see, we have fairly extreme class imbalance in our dataset. Only $0.13$% of our examples indicate that a fire has occurred! Therefore, we may need to use techniques like `class_weight` balancing or `SMOTE` sampling to achieve optimal results. To conclude, because of this extreme class imbalance, we will be evaluating our models using metrics which are more indicative of good performance in these situations. Namely, we will use the `average_percision` and `roc_auc` evaluation metrics. These metrics, unlike `f1`, `recall`, or `precision`, evaluate models based on the probability of a target class being picked, rather than the model's actual prediction accuracy on the train and test datasets.

# %% [markdown]
# <br>

# %%
plt.figure(figsize=(40, 40))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap=plt.cm.Blues)
plt.show()

# %% [markdown]
# The above heatmap displays how correlated the various features are with one another. Unsurprisingly, features coming from the same MODIS datasets show a high correlation with one another: `Land Surface Temperature`, `Emissivity`, and `Surface Reflection`. Examining the heatmap, we can see that the feature `lst_day` is correlated with the features `sur_refl_b06` ($0.4$) and `sur_refl_b07` ($0.38$). We can also see that the feature `region` is correlated with the features `emis_31` ($0.22$) and `emis_32` ($0.24$) It appears that no feature shows a high correlation with the `fire_today` feature, however there is no need for concern as the model will hopefully find other relationships.

# %% [markdown]
# <br>

# %%
numeric_features = [
    'lst_day',
    'lst_night',
    'emis_31',
    'emis_32',
    'sur_refl_b01',
    'sur_refl_b02',
    'sur_refl_b03',
    'sur_refl_b04',
    'sur_refl_b05',
    'sur_refl_b06',
    'sur_refl_b07',
]

negative_examples = df[df['fire_today'] == 0]
positive_examples = df[df['fire_today'] == 1]

for feature in numeric_features:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(40, 10))
    fig.suptitle('Distribution of Feature "%s"' % feature)
    sns.histplot(negative_examples[feature], ax=ax1)
    sns.histplot(positive_examples[feature], ax=ax2)
    plt.show()

# %% [markdown]
# The graphs above are separated into no fire (`fire_today` of $0$) in the first column and fire (`fire_today` of $1$) in the second column. Ignoring the features `date`, `time`, `longitude`, `latitude`, `region`, `month`, and `year` a few patterns seem to emerge for the remaining numeric features. Most of the `Surface Reflection` features appear to be positively skewed, with the majority of their values being less than $3,000$. The `Land Surface Temperature` features appear to be more-or-less normally distributed. Lastly, the `Emissivity` features have fairly strange distributions, containing a few outliers. If we examine the `sur_refl_b01`, `sur_refl_b03`, and `sur_refl_b04` features we see that the graphs in the first column are centered around $1,000$, $500$, and $500$, respectively. Interestingly, if we examine the second column, we see that the graphs are centered around ~$2,000$. There is a good chance that our classifier model will uncover this relationship and use it to make predictions. We will examine feature importance after we train our model.

# %% [markdown]
# <br>

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(40, 10))
fig.suptitle('Distribution of Fire by Region, Month, and Year')
sns.histplot(positive_examples['region'], ax=ax1)
sns.histplot(positive_examples['month'], ax=ax2)
sns.histplot(positive_examples['year'], ax=ax3)
plt.show()

# %% [markdown]
# The three graphs above show the count of fire occurrences per `region`, `month`, and `year`. The regions, as stated above, are assigned per bounding box while collecting the data. There are $1550$ regions in total. Because we collected our data from West to East and then South to North, the lower the region number, the lower the latitude. Looking at the `region` graph, it appears that more wildfires are occurring in the Northern regions of Mendocino National Forest. Examining the `month` graph, it seems that August and September are the worst months for wildfires. Lastly, examining the `year` graph, we see that $2018$ and $2020$ were terrible years for wildfires, while $2019$ and $2021$ weren't.

# %% [markdown]
# <br><br>

# %% [markdown]
# ## 4. Feature Engineering
# <hr><br>

# %% [markdown]
# The main form of feature engineering we'll perform is extracting lagged features from our existing features. Lagged features are simply the values for a given feature from a previous day or days. We'll impute and encode these lagged features exactly the same as their non-lagged counterparts.

# %%
def lagFeatures(df, features, shift, feature_name=None, clip=False, sortby=['region', 'date'], groupby='region'):
    copy = df.copy()
    copy.sort_values(by=sortby)
    for name, group in copy.groupby(groupby):
        for feature in features:
            for n in shift:
                copy.loc[group.index, feature + '_lag_' + str(n) if feature_name is None else feature_name] = group[feature].shift(n)
    if clip:
        copy = copy.dropna(subset=feature_name)
    return copy

lag_df = lagFeatures(df, numeric_features, [1, 2, 3])
lag_df = lagFeatures(lag_df, ['fire_today'], [-1], 'fire_tomorrow', True)
lag_df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2261450 entries, 0 to 2262998
# Data columns (total 53 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   date                2261450 non-null  datetime64[ns]
#  1   longitude           2261450 non-null  float64
#  2   latitude            2261450 non-null  float64
#  3   time                2261450 non-null  float64
#  4   fire_today          2261450 non-null  int64
#  5   lst_day             1586258 non-null  float64
#  6   lst_night           1522451 non-null  float64
#  7   emis_31             1831507 non-null  float64
#  8   emis_32             1831507 non-null  float64
#  9   sur_refl_b01        2252150 non-null  float64
#  10  sur_refl_b02        2252132 non-null  float64
#  11  sur_refl_b03        2252150 non-null  float64
#  12  sur_refl_b04        2252150 non-null  float64
#  13  sur_refl_b05        2252150 non-null  float64
#  14  sur_refl_b06        2252150 non-null  float64
#  15  sur_refl_b07        2252147 non-null  float64
#  16  region              2261450 non-null  int64
#  17  month               2261450 non-null  object
#  18  year                2261450 non-null  int64
#  19  lst_day_lag_1       1585351 non-null  float64
#  20  lst_day_lag_2       1584553 non-null  float64
#  21  lst_day_lag_3       1584344 non-null  float64
#  22  lst_night_lag_1     1521431 non-null  float64
#  23  lst_night_lag_2     1521431 non-null  float64
#  24  lst_night_lag_3     1521374 non-null  float64
#  25  emis_31_lag_1       1830124 non-null  float64
#  26  emis_31_lag_2       1829326 non-null  float64
#  27  emis_31_lag_3       1829061 non-null  float64
#  28  emis_32_lag_1       1830124 non-null  float64
#  29  emis_32_lag_2       1829326 non-null  float64
#  30  emis_32_lag_3       1829061 non-null  float64
#  31  sur_refl_b01_lag_1  2250600 non-null  float64
#  32  sur_refl_b01_lag_2  2249050 non-null  float64
#  33  sur_refl_b01_lag_3  2247500 non-null  float64
#  34  sur_refl_b02_lag_1  2250582 non-null  float64
#  35  sur_refl_b02_lag_2  2249032 non-null  float64
#  36  sur_refl_b02_lag_3  2247482 non-null  float64
#  37  sur_refl_b03_lag_1  2250600 non-null  float64
#  38  sur_refl_b03_lag_2  2249050 non-null  float64
#  39  sur_refl_b03_lag_3  2247500 non-null  float64
#  40  sur_refl_b04_lag_1  2250600 non-null  float64
#  41  sur_refl_b04_lag_2  2249050 non-null  float64
#  42  sur_refl_b04_lag_3  2247500 non-null  float64
#  43  sur_refl_b05_lag_1  2250600 non-null  float64
#  44  sur_refl_b05_lag_2  2249050 non-null  float64
#  45  sur_refl_b05_lag_3  2247500 non-null  float64
#  46  sur_refl_b06_lag_1  2250600 non-null  float64
#  47  sur_refl_b06_lag_2  2249050 non-null  float64
#  48  sur_refl_b06_lag_3  2247500 non-null  float64
#  49  sur_refl_b07_lag_1  2250597 non-null  float64
#  50  sur_refl_b07_lag_2  2249047 non-null  float64
#  51  sur_refl_b07_lag_3  2247497 non-null  float64
#  52  fire_tomorrow       2261450 non-null  float64
# dtypes: datetime64[ns](1), float64(48), int64(3), object(1)
# memory usage: 931.7+ MB

# %% [markdown]
# For each of our numeric features, we now have a lagged version of that feature for the previous three days. Going row by row you can see the triangular pattern of NaNs appearing as features begin to be lagged. The first row, of course, contains NaNs for all our lagged features as it has no previous day to extract data from. Most importantly, we have defined our target variable for this analysis - `fire_tomorrow` - by looking at the `fire_today` field for the next day and extracting that for our target. This will allow us to train our model in a way that ideally allow us to predict if fire will occur the following day. The goal is forecasting wildfires so that individuals and organizations can act in a preemptive manner.

# %% [markdown]
# <br><br>

# %% [markdown]
# ## 5. Data Splitting
# <hr><br>

# %% [markdown]
# Because our dataset is a time series, we are unable to randomly split our data using conventional methods like `train_test_split`. In order to preserve a train/test split ratio of $75$:$25$, we'll take all data before $2021$ as our training set and all data after and including $2021$ as our testing set.

# %%
train_df = lag_df.query('date < 20210101')
test_df = lag_df.query('date >= 20210101')
print('Ratio of Training data: %.3f' % (len(train_df) / (len(train_df) + len(test_df))))
# Out:
# Ratio of Training data: 0.751

# %% [markdown]
# <br><br>

# %% [markdown]
# ## 6. Preprocessing & Transformations
# <hr><br>

# %%
X_train = train_df.drop(columns=['fire_tomorrow'])
X_test = test_df.drop(columns=['fire_tomorrow'])
y_train = train_df['fire_tomorrow']
y_test = test_df['fire_tomorrow']

numeric_features = [
    'time',
    'region',
    'lst_day',
    'lst_day_lag_1',
    'lst_day_lag_2',
    'lst_day_lag_3',
    'lst_night',
    'lst_night_lag_1',
    'lst_night_lag_2',
    'lst_night_lag_3',
    'emis_31',
    'emis_31_lag_1',
    'emis_31_lag_2',
    'emis_31_lag_3',
    'emis_32',
    'emis_32_lag_1',
    'emis_32_lag_2',
    'emis_32_lag_3',
    'sur_refl_b01',
    'sur_refl_b01_lag_1',
    'sur_refl_b01_lag_2',
    'sur_refl_b01_lag_3',
    'sur_refl_b02',
    'sur_refl_b02_lag_1',
    'sur_refl_b02_lag_2',
    'sur_refl_b02_lag_3',
    'sur_refl_b03',
    'sur_refl_b03_lag_1',
    'sur_refl_b03_lag_2',
    'sur_refl_b03_lag_3',
    'sur_refl_b04',
    'sur_refl_b04_lag_1',
    'sur_refl_b04_lag_2',
    'sur_refl_b04_lag_3',
    'sur_refl_b05',
    'sur_refl_b05_lag_1',
    'sur_refl_b05_lag_2',
    'sur_refl_b05_lag_3',
    'sur_refl_b06',
    'sur_refl_b06_lag_1',
    'sur_refl_b06_lag_2',
    'sur_refl_b06_lag_3',
    'sur_refl_b07',
    'sur_refl_b07_lag_1',
    'sur_refl_b07_lag_2',
    'sur_refl_b07_lag_3',
]

categorical_features = [
    'month',
    'year',
]

passthrough_features = [
    'fire_today'
]

drop_features = [
    'date',
    'longitude',
    'latitude',
]

preprocessor = make_column_transformer(
    ('passthrough', passthrough_features),
    ('drop', drop_features),
    (make_pipeline(SimpleImputer(), StandardScaler()), numeric_features),
    (OneHotEncoder(handle_unknown='ignore'), categorical_features),
)

# %% [markdown]
# As we stated above, with the exception of `date` and `month`, all of our features are numeric. Therefore, we will use `SimpleImputer` and `StandardScaler` to impute and scale our feature values, respectively. For the `month`, and `year` features we will treat these as categorical variables and use one-hot encoding, creating a new column for each unique value these features can take on. We have decided to drop the `date`, `longitude`, and `latitude` fields as they likely won't provide our model with any useful information beyond what we've already been able to extract. Of course, we could try different approaches to data transformations to potentially improve the model after our analysis is complete.

# %% [markdown]
# <br><br>

# %% [markdown]
# ## 7. Evaluating Classifiers with Model-Based Class Balancing
# <hr><br>

# %%
columns = ['Model', 'AP Train Score', 'AP Test Score', 'ROC Train Score', 'ROC Test Score']
scale_pos_weight = np.bincount(y_train)[0] / np.bincount(y_train)[1]
models = {
    'DummyClassifier': DummyClassifier(),
    'LogisticRegression': LogisticRegression(class_weight='balanced', max_iter=5000),
    'XGBClassifier': XGBClassifier(scale_pos_weight=scale_pos_weight),
    'LGBMClassifier': LGBMClassifier(scale_pos_weight=scale_pos_weight),
}

def crossValidateSummary(model, X_train, y_train, scoring=['average_precision', 'roc_auc']):
    scores = cross_validate(
        model, 
        X_train, 
        y_train, 
        scoring=scoring,
        return_train_score=True,
        n_jobs=-1
    )
    return [
        ('%0.3f (+/- %0.3f)' % (scores['train_average_precision'].mean(), scores['train_average_precision'].std())),
        ('%0.3f (+/- %0.3f)' % (scores['test_average_precision'].mean(), scores['test_average_precision'].std())),
        ('%0.3f (+/- %0.3f)' % (scores['train_roc_auc'].mean(), scores['train_roc_auc'].std())),
        ('%0.3f (+/- %0.3f)' % (scores['test_roc_auc'].mean(), scores['test_roc_auc'].std())),
    ]

def evaluateModels(X_train=X_train, y_train=y_train, models=models, preprocessor=preprocessor, sampler=False):
    summary = []
    for name, model in models.items():
        pipe = make_pipeline(preprocessor, model) if sampler is False else imb_make_pipeline(preprocessor, SMOTE(), model)
        scores = crossValidateSummary(pipe, X_train, y_train)
        summary.append([name if sampler is False else name + ' (smote)', scores[0], scores[1], scores[2], scores[3]])
    return summary

summary = evaluateModels()
pd.DataFrame(summary, columns=columns).set_index('Model')
# Out:
#                        AP Train Score      AP Test Score    ROC Train Score  \
# Model
# DummyClassifier     0.002 (+/- 0.000)  0.002 (+/- 0.000)  0.500 (+/- 0.000)
# LogisticRegression  0.205 (+/- 0.013)  0.189 (+/- 0.021)  0.986 (+/- 0.002)
# XGBClassifier       0.922 (+/- 0.016)  0.055 (+/- 0.036)  1.000 (+/- 0.000)
# LGBMClassifier      0.023 (+/- 0.008)  0.016 (+/- 0.006)  0.930 (+/- 0.022)
#
#                        ROC Test Score
# Model
# DummyClassifier     0.500 (+/- 0.000)
# LogisticRegression  0.962 (+/- 0.032)
# XGBClassifier       0.887 (+/- 0.068)
# LGBMClassifier      0.812 (+/- 0.145)

# %% [markdown]
# Examining the scores above, it appears that our `LogisticRegression` model obtains the best `roc_auc` test score ($0.962$), followed by our `XGBClassifier` model ($0.887$), and then our `LGBMClassifier` model ($0.812$). For all three models, the `average_precision` test scores are much worse than the `roc_auc` test scores. This is likely due to the fact that we have so few positive examples ($0.13$%). Furthermore, if we examine the `roc_auc` training scores, it appears the `LogisticRegression` and `XGBClassifier` models are overfitting as they score close to $100$%. Before we perform hyperparameter optimization, it may benefit our models to use a technique like SMOTE to balance our data.

# %% [markdown]
# <br><br>

# %% [markdown]
# ## 8. Evaluating Classifiers with Sampling-Based Class Balancing
# <hr><br>

# %%
models = {
    'DummyClassifier': DummyClassifier(),
    'LogisticRegression': LogisticRegression(max_iter=5000),
    'XGBClassifier': XGBClassifier(),
    'LGBMClassifier': LGBMClassifier(),
}

smote_summary = evaluateModels(models=models, sampler=True)
pd.DataFrame(np.concatenate((summary, smote_summary)), columns=columns).set_index('Model')
# Out:
#                                AP Train Score      AP Test Score  \
# Model
# DummyClassifier             0.002 (+/- 0.000)  0.002 (+/- 0.000)
# LogisticRegression          0.205 (+/- 0.013)  0.189 (+/- 0.021)
# XGBClassifier               0.922 (+/- 0.016)  0.055 (+/- 0.036)
# LGBMClassifier              0.023 (+/- 0.008)  0.016 (+/- 0.006)
# DummyClassifier (smote)     0.002 (+/- 0.000)  0.002 (+/- 0.000)
# LogisticRegression (smote)  0.216 (+/- 0.013)  0.200 (+/- 0.019)
# XGBClassifier (smote)       0.737 (+/- 0.014)  0.091 (+/- 0.052)
# LGBMClassifier (smote)      0.472 (+/- 0.027)  0.163 (+/- 0.068)
#
#                               ROC Train Score     ROC Test Score
# Model
# DummyClassifier             0.500 (+/- 0.000)  0.500 (+/- 0.000)
# LogisticRegression          0.986 (+/- 0.002)  0.962 (+/- 0.032)
# XGBClassifier               1.000 (+/- 0.000)  0.887 (+/- 0.068)
# LGBMClassifier              0.930 (+/- 0.022)  0.812 (+/- 0.145)
# DummyClassifier (smote)     0.500 (+/- 0.000)  0.500 (+/- 0.000)
# LogisticRegression (smote)  0.986 (+/- 0.002)  0.962 (+/- 0.030)
# XGBClassifier (smote)       0.999 (+/- 0.000)  0.932 (+/- 0.048)
# LGBMClassifier (smote)      0.997 (+/- 0.001)  0.941 (+/- 0.022)

# %% [markdown]
# Examining the scores above, it appears that switching from a model-based class balancing approach to a sampling-based balancing approach has improved all of our models quite a bit. Our `LogisticRegression` model obtains the best `roc_auc` test score ($0.962$), followed by our `LGBMClassifier` model ($0.941$), and then our `XGBClassifier` model ($0.932$). Once again, for all three models, the `average_precision` test scores are much worse than the `roc_auc` test scores. Furthermore, if we examine the `roc_auc` training scores, it appears that all of our models are overfitting as they score close to $100$%. Next we will perform hyperparameter optimization on our `LGBMClassifier` model.

# %% [markdown]
# <br><br>

# %% [markdown]
# ## 9. Hyperparameter Optimization
# <hr><br>

# %%
lgbm_random_search = RandomizedSearchCV(
    imb_make_pipeline(preprocessor, SMOTE(), LGBMClassifier()), 
    {
        'lgbmclassifier__boosting_type': ['gbdt', 'dart'],
        'lgbmclassifier__learning_rate': [0.01, 0.05, 0.1, 0.15, 0.3],
        'lgbmclassifier__max_bin': [100, 200, 300, 400, 500],
        'lgbmclassifier__n_estimators': [50, 75, 100, 125, 150],
        'lgbmclassifier__num_leaves': [10, 20, 30, 40, 50],

    }, 
    scoring='roc_auc',
    return_train_score=True,
    n_iter=100,
    n_jobs=-1,
)

lgbm_random_search.fit(X_train, y_train)
print('Best hyperparameter values: ', lgbm_random_search.best_params_)
print('Best score: %0.3f' % lgbm_random_search.best_score_)
# Out:
# /Users/lukebasso/miniconda3/envs/cpsc330/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Best hyperparameter values:  {'lgbmclassifier__num_leaves': 10, 'lgbmclassifier__n_estimators': 50, 'lgbmclassifier__max_bin': 300, 'lgbmclassifier__learning_rate': 0.05, 'lgbmclassifier__boosting_type': 'gbdt'}
# Best score: 0.979

# %% [markdown]
# <br>

# %%
pd.DataFrame(lgbm_random_search.cv_results_)[[
    'rank_test_score',
    'mean_fit_time',
    'mean_train_score',
    'mean_test_score',
    'param_lgbmclassifier__boosting_type',
    'param_lgbmclassifier__learning_rate',
    'param_lgbmclassifier__max_bin',
    'param_lgbmclassifier__n_estimators',
    'param_lgbmclassifier__num_leaves',
]].set_index('rank_test_score').sort_index().head(20)
# Out:
#                  mean_fit_time  mean_train_score  mean_test_score  \
# rank_test_score
# 1                    56.218880          0.991774         0.978842
# 2                   203.859105          0.993896         0.975348
# 3                    84.557574          0.989316         0.975288
# 4                    69.960783          0.995111         0.974875
# 5                    55.382445          0.995004         0.973978
# 6                   205.932741          0.994234         0.973505
# 7                   128.194408          0.993933         0.973464
# 8                   129.589496          0.994927         0.972456
# 9                   282.977155          0.994593         0.972097
# 10                   45.029309          0.996677         0.972035
# 11                   92.514457          0.996430         0.972003
# 12                  111.031184          0.995444         0.971838
# 13                  146.545016          0.994224         0.971708
# 14                  128.749450          0.994978         0.971623
# 15                   47.702128          0.984299         0.971560
# 16                  132.454919          0.995120         0.971294
# 17                  145.826087          0.993965         0.970867
# 18                   82.623527          0.995076         0.970467
# 19                  176.310904          0.996359         0.970459
# 20                   86.466644          0.995830         0.970333
#
#                 param_lgbmclassifier__boosting_type  \
# rank_test_score
# 1                                              gbdt
# 2                                              dart
# 3                                              gbdt
# 4                                              gbdt
# 5                                              gbdt
# 6                                              dart
# 7                                              dart
# 8                                              dart
# 9                                              dart
# 10                                             gbdt
# 11                                             dart
# 12                                             dart
# 13                                             dart
# 14                                             dart
# 15                                             gbdt
# 16                                             dart
# 17                                             dart
# 18                                             dart
# 19                                             dart
# 20                                             gbdt
#
#                 param_lgbmclassifier__learning_rate  \
# rank_test_score
# 1                                              0.05
# 2                                              0.05
# 3                                              0.01
# 4                                              0.05
# 5                                              0.05
# 6                                              0.05
# 7                                               0.1
# 8                                              0.15
# 9                                              0.05
# 10                                              0.1
# 11                                              0.1
# 12                                              0.1
# 13                                              0.1
# 14                                             0.15
# 15                                             0.01
# 16                                             0.15
# 17                                             0.05
# 18                                              0.1
# 19                                              0.1
# 20                                             0.05
#
#                 param_lgbmclassifier__max_bin  \
# rank_test_score
# 1                                         300
# 2                                         200
# 3                                         300
# 4                                         300
# 5                                         100
# 6                                         500
# 7                                         500
# 8                                         100
# 9                                         400
# 10                                        100
# 11                                        100
# 12                                        200
# 13                                        500
# 14                                        200
# 15                                        200
# 16                                        400
# 17                                        500
# 18                                        500
# 19                                        100
# 20                                        500
#
#                 param_lgbmclassifier__n_estimators  \
# rank_test_score
# 1                                               50
# 2                                              150
# 3                                              150
# 4                                               75
# 5                                               75
# 6                                              125
# 7                                              125
# 8                                              125
# 9                                              150
# 10                                              50
# 11                                              75
# 12                                             100
# 13                                             150
# 14                                             125
# 15                                              75
# 16                                             125
# 17                                             100
# 18                                              50
# 19                                             125
# 20                                              75
#
#                 param_lgbmclassifier__num_leaves
# rank_test_score
# 1                                             10
# 2                                             20
# 3                                             10
# 4                                             30
# 5                                             30
# 6                                             30
# 7                                             10
# 8                                             10
# 9                                             30
# 10                                            40
# 11                                            50
# 12                                            20
# 13                                            10
# 14                                            10
# 15                                            10
# 16                                            10
# 17                                            30
# 18                                            30
# 19                                            30
# 20                                            40

# %% [markdown]
# <br>

# %%
best_lgbm_model = lgbm_random_search.best_estimator_
scores = crossValidateSummary(best_lgbm_model, X_train, y_train)
pd.DataFrame(np.concatenate((summary, smote_summary, [['LGBMClassifier (tuned w/ smote)', scores[0], scores[1], scores[2], scores[3]]])), columns=columns).set_index('Model')
# Out:
#                                     AP Train Score      AP Test Score  \
# Model
# DummyClassifier                  0.002 (+/- 0.000)  0.002 (+/- 0.000)
# LogisticRegression               0.205 (+/- 0.013)  0.189 (+/- 0.021)
# XGBClassifier                    0.922 (+/- 0.016)  0.055 (+/- 0.036)
# LGBMClassifier                   0.023 (+/- 0.008)  0.016 (+/- 0.006)
# DummyClassifier (smote)          0.002 (+/- 0.000)  0.002 (+/- 0.000)
# LogisticRegression (smote)       0.216 (+/- 0.013)  0.200 (+/- 0.019)
# XGBClassifier (smote)            0.737 (+/- 0.014)  0.091 (+/- 0.052)
# LGBMClassifier (smote)           0.472 (+/- 0.027)  0.163 (+/- 0.068)
# LGBMClassifier (tuned w/ smote)  0.223 (+/- 0.014)  0.190 (+/- 0.030)
#
#                                    ROC Train Score     ROC Test Score
# Model
# DummyClassifier                  0.500 (+/- 0.000)  0.500 (+/- 0.000)
# LogisticRegression               0.986 (+/- 0.002)  0.962 (+/- 0.032)
# XGBClassifier                    1.000 (+/- 0.000)  0.887 (+/- 0.068)
# LGBMClassifier                   0.930 (+/- 0.022)  0.812 (+/- 0.145)
# DummyClassifier (smote)          0.500 (+/- 0.000)  0.500 (+/- 0.000)
# LogisticRegression (smote)       0.986 (+/- 0.002)  0.962 (+/- 0.030)
# XGBClassifier (smote)            0.999 (+/- 0.000)  0.932 (+/- 0.048)
# LGBMClassifier (smote)           0.997 (+/- 0.001)  0.941 (+/- 0.022)
# LGBMClassifier (tuned w/ smote)  0.992 (+/- 0.001)  0.979 (+/- 0.014)

# %% [markdown]
# Using `RandomizedSearchCV` we were able to perform hyperparameter optimization on our `LGBMClassifier` model. Examining the table above, we see that our tuned `LGBMClassifier` model performs much better, obtaining a `roc_auc` test score of $0.979$! There could be a number of reasons for this. First, our model may have simply lucked out during testing and scored exceptionally well. However, it could be that this combination of hyperparameters reduces overfitting and increases prediction performance. The default values for `boosting_type`, `learning_rate`, `max_bin`, `n_estimators`, and `num_leaves` are `gbdt`, $0.1$, $255$, $100$, and $31$, respectively. These would have been the hyperparameter values our untuned `LGBMClassifier` model used. We see above that this combination of hyperparameter values doesn't appear in the top $20$ combinations. It could be, however, that this combination of hyperparameter values wasn't picked by our `RandomizedSearchCV`. Noting the `mean_fit_time` for each run, this search took ~$3$ hours to complete!

# %% [markdown]
# <br><br>

# %% [markdown]
# ## 10. Feature Interpretation
# <hr><br>

# %%
categorical_OHE = list(
    best_lgbm_model
    .named_steps['columntransformer']
    .named_transformers_['onehotencoder']
    .get_feature_names_out(categorical_features)
)
feature_names = numeric_features + passthrough_features + categorical_OHE
eli5.show_weights(best_lgbm_model.named_steps["lgbmclassifier"], feature_names=feature_names)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.5004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 region
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.22%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1544
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 month_August
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.04%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0887
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 time
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0871
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lst_day
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.57%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0581
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 emis_31
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.47%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0262
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sur_refl_b03_lag_1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.79%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0215
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lst_night_lag_1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.68%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0103
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sur_refl_b03_lag_2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.68%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0103
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sur_refl_b03_lag_3
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.77%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0093
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lst_night_lag_2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.78%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0093
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 month_September
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.26%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0045
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 year_2019
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.30%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0042
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sur_refl_b07_lag_3
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.39%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0034
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lst_night_lag_3
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.50%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0026
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lst_day_lag_1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.54%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0023
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sur_refl_b04_lag_2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.59%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0020
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sur_refl_b02_lag_2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.68%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sur_refl_b02_lag_3
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 month_November
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.75%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sur_refl_b04
#             </t

# %% [markdown]
# The above table, calculated using the library `eli5`, displays the weight our tuned model gave to each of our features. The higher the weight, the higher the importance of the feature when predicting our target variable `fire_tomorrow`. As we can see, our model determined that `region` was the most important feature, giving it a weight of $0.5004$, followed by `month_August` with a weight of $0.1544$ and `time` with a weight of $0.0887$. Perhaps surprising, `fire_today`, the feature we used to calculate our target variable, doesn't appear in the table. Meaning our model determined it wasn't useful for prediction. Again, this could be because of the low number of positive examples ($0.13$%) in our dataset.

# %% [markdown]
# <br><br>

# %% [markdown]
# ## 11. Results on the Test Set
# <hr><br>

# %%
print('ROC score: %.3f' % roc_auc_score(y_test, best_lgbm_model.predict_proba(X_test)[:, 1]))
# Out:
# ROC score: 0.873

# %% [markdown]
# Now that we have tuned our model, we can use it on the test data split to obtain a `roc_auc` score on unseen examples. Recall that earlier that we separated our data in before $2021$ and after including $2021$. Therefore, we see that our tuned model obtains a `roc_auc` score of $0.873$ on our test set. While this isn't entirely great, it is fairly good for a model trained on limited data with a low number of positive examples ($0.13$%). Because we're using the `roc_auc` metric, we calculate the probability our tuned model predicts our target variable, `fire_tomorrow`, using the function `predict_proba`. Again, this isn't our tuned model's prediction accuracy on the test set, rather the model's prediction probability.

# %% [markdown]
# <br>

# %%
fpr, tpr, thresholds = roc_curve(y_test, best_lgbm_model.predict_proba(X_test)[:, 1])
plt.plot(fpr, tpr, label="ROC Curve")
plt.xlabel("FPR")
plt.ylabel("TPR (Recall)")
plt.show()

# %% [markdown]
# The graph above is known as a ROC Curve (Receiver Operating Characteristic Curve). More information regarding this metric and graph can be found [here](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc). As written in the article, the ROC Curve is a plot of the True Positive Rate, otherwise known as Recall, over the False Positive Rate across different classification thresholds. In other words, if we increase or reduce the probability our model predicts the target variable, `fire_tomorrow`, how does this model score on TPR and FPR. So, as we can see in the above graph, our model obtains a TPR of approximately $0.9$ at a FPR of $0.6$. This seems acceptable as our model is over predicting False Positives, meaning it predicts a fire tomorrow when there is no fire.

# %% [markdown]
# <br><br>

# %% [markdown]
# ## 12. Summary
# <hr><br>

# %% [markdown]
# This project was a great way to practice the steps involved in typical machine learning analysis. We went from data extraction to data exploration, feature engineering, data preprocessing and tranformation, evaluating classifiers using model-based balancing, evaluating classifiers using sampling-based balancing, hyperparameter optimization, and evaluating our tuned `LGBMClassifier` on the test set. In the end, our model obtained a `roc_auc` score of $0.873$, meaning the probability it classifies a randomly picked example as `fire_tomorrow=1` over `fire_tomorrow=0` is $87$%. While this isn't exactly the performance we wanted, it is decent given the limited data and low number of positive examples ($0.13$%).
